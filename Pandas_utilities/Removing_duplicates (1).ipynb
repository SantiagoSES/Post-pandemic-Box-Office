# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("cleansed9_fmbp_oneencoded.csv")

df = df.drop_duplicates(subset=['movie_id', 'movie_name', 'year', 'budget'])

# Save back to CSV
df.to_csv("cleansed10_fmbp_oneencoded.csv", index=False)
