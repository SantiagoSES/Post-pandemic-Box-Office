# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("Hypothesis.csv")

df['budget'] = df['budget'].astype(int)
df['worldwide_gross'] = df['worldwide_gross'].astype(int)

df['is_profitable'] = 2.5 * df['budget'] <= df['worldwide_gross']

#df['Release Date'] = pd.to_datetime(df['Release Date'])
#df['month_number'] = df['Release Date'].dt.month

# Save back to CSV
df.to_csv("Final_Hypothesis.csv", index=False)
